# %%
import os
import pandas as pd
import numpy as np

from IPython import get_ipython


from sklearn.metrics import mean_absolute_error as mae

import matplotlib.pyplot as plt
get_ipython().run_line_magic('matplotlib', 'inline')

import seaborn as sns
sns.set()

import plotly
import plotly.express as px
import plotly.graph_objs as go
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
import plotly.io as pio
init_notebook_mode(connected=True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
path = './data/time_series_covid19_confirmed_global.csv'
df = pd.read_csv(path)
df.head(10)
# Out:
#                  Province/State       Country/Region      Lat      Long  \
# 0                           NaN          Afghanistan  33.0000   65.0000
# 1                           NaN              Albania  41.1533   20.1683
# 2                           NaN              Algeria  28.0339    1.6596
# 3                           NaN              Andorra  42.5063    1.5218
# 4                           NaN               Angola -11.2027   17.8739
# 5                           NaN  Antigua and Barbuda  17.0608  -61.7964
# 6                           NaN            Argentina -38.4161  -63.6167
# 7                           NaN              Armenia  40.0691   45.0382
# 8  Australian Capital Territory            Australia -35.4735  149.0124
# 9               New South Wales            Australia -33.8688  151.2093
#
#    1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  ...  3/13/20  \
# 0        0        0        0        0        0        0  ...        7
# ...

# %%
df['country_region'] = df['Country/Region'] + '_' + df['Province/State'].map(lambda x: str(x))
df.head(20)
# Out:
#                   Province/State       Country/Region      Lat      Long  \
# 0                            NaN          Afghanistan  33.0000   65.0000
# 1                            NaN              Albania  41.1533   20.1683
# 2                            NaN              Algeria  28.0339    1.6596
# 3                            NaN              Andorra  42.5063    1.5218
# 4                            NaN               Angola -11.2027   17.8739
# 5                            NaN  Antigua and Barbuda  17.0608  -61.7964
# 6                            NaN            Argentina -38.4161  -63.6167
# 7                            NaN              Armenia  40.0691   45.0382
# 8   Australian Capital Territory            Australia -35.4735  149.0124
# 9                New South Wales            Australia -33.8688  151.2093
# 10            Northern Territory            Australia -12.4634  130.8456
# 11                    Queensland            Australia -28.0167  153.4000
# ...

# %%
df.columns
# Out:
# Index(['Province/State', 'Country/Region', 'Lat', 'Long', '1/22/20', '1/23/20',
#        '1/24/20', '1/25/20', '1/26/20', '1/27/20', '1/28/20', '1/29/20',
#        '1/30/20', '1/31/20', '2/1/20', '2/2/20', '2/3/20', '2/4/20', '2/5/20',
#        '2/6/20', '2/7/20', '2/8/20', '2/9/20', '2/10/20', '2/11/20', '2/12/20',
#        '2/13/20', '2/14/20', '2/15/20', '2/16/20', '2/17/20', '2/18/20',
#        '2/19/20', '2/20/20', '2/21/20', '2/22/20', '2/23/20', '2/24/20',
#        '2/25/20', '2/26/20', '2/27/20', '2/28/20', '2/29/20', '3/1/20',
#        '3/2/20', '3/3/20', '3/4/20', '3/5/20', '3/6/20', '3/7/20', '3/8/20',
#        '3/9/20', '3/10/20', '3/11/20', '3/12/20', '3/13/20', '3/14/20',
#        '3/15/20', '3/16/20', '3/17/20', '3/18/20', '3/19/20', '3/20/20',
#        '3/21/20', '3/22/20', 'country_region'],
#       dtype='object')

# %%
result_path = './data/time_series_20200323.csv'
result_df = pd.read_csv(result_path)
result_df.head(10)
# Out:
# Empty DataFrame
# Columns: [date, country, region, lat, long, confirmed, deaths]
# Index: []

# %%
dates = ['1/22/20', '1/23/20',
       '1/24/20', '1/25/20', '1/26/20', '1/27/20', '1/28/20', '1/29/20',
       '1/30/20', '1/31/20', '2/1/20', '2/2/20', '2/3/20', '2/4/20', '2/5/20',
       '2/6/20', '2/7/20', '2/8/20', '2/9/20', '2/10/20', '2/11/20', '2/12/20',
       '2/13/20', '2/14/20', '2/15/20', '2/16/20', '2/17/20', '2/18/20',
       '2/19/20', '2/20/20', '2/21/20', '2/22/20', '2/23/20', '2/24/20',
       '2/25/20', '2/26/20', '2/27/20', '2/28/20', '2/29/20', '3/1/20',
       '3/2/20', '3/3/20', '3/4/20', '3/5/20', '3/6/20', '3/7/20', '3/8/20',
       '3/9/20', '3/10/20', '3/11/20', '3/12/20', '3/13/20', '3/14/20',
       '3/15/20', '3/16/20', '3/17/20', '3/18/20', '3/19/20', '3/20/20',
       '3/21/20', '3/22/20']

# %%
result_columns = result_df.columns

# %%
for index, row in df.iterrows():
    for date in dates:
        isert_row = [date, row['Country/Region'], row['Province/State'], row['Lat'], row['Long'], row[date], 0]        
        new_df = pd.DataFrame([isert_row], columns=result_columns)
        print(new_df)
        result_df = result_df.append(new_df)
# Out:
#   0
#      date     country  region        lat       long  confirmed  deaths
# 0  3/3/20  Mozambique     NaN -18.665695  35.529562          0       0
#      date     country  region        lat       long  confirmed  deaths
# 0  3/4/20  Mozambique     NaN -18.665695  35.529562          0       0
#      date     country  region        lat       long  confirmed  deaths
# 0  3/5/20  Mozambique     NaN -18.665695  35.529562          0       0
#      date     country  region        lat       long  confirmed  deaths
# 0  3/6/20  Mozambique     NaN -18.665695  35.529562          0       0
#      date     country  region        lat       long  confirmed  deaths
# 0  3/7/20  Mozambique     NaN -18.665695  35.529562          0       0
#      date     country  region        lat       long  confirmed  deaths
# 0  3/8/20  Mozambique     NaN -18.665695  35.529562          0       0
#      date     country  region        lat       long  confirmed  deaths
# ...

# %%
result_df.head(20)
# Out:
#       date      country region   lat  long confirmed deaths
# 0  1/22/20  Afghanistan    NaN  33.0  65.0         0      0
# 0  1/23/20  Afghanistan    NaN  33.0  65.0         0      0
# 0  1/24/20  Afghanistan    NaN  33.0  65.0         0      0
# 0  1/25/20  Afghanistan    NaN  33.0  65.0         0      0
# 0  1/26/20  Afghanistan    NaN  33.0  65.0         0      0
# 0  1/27/20  Afghanistan    NaN  33.0  65.0         0      0
# 0  1/28/20  Afghanistan    NaN  33.0  65.0         0      0
# 0  1/29/20  Afghanistan    NaN  33.0  65.0         0      0
# 0  1/30/20  Afghanistan    NaN  33.0  65.0         0      0
# 0  1/31/20  Afghanistan    NaN  33.0  65.0         0      0
# 0   2/1/20  Afghanistan    NaN  33.0  65.0         0      0
# 0   2/2/20  Afghanistan    NaN  33.0  65.0         0      0
# 0   2/3/20  Afghanistan    NaN  33.0  65.0         0      0
# 0   2/4/20  Afghanistan    NaN  33.0  65.0         0      0
# 0   2/5/20  Afghanistan    NaN  33.0  65.0         0      0
# ...

# %%
result_df.size
# Out:
# 101199

# %%
result_df.to_csv('./data/time_series_20200323.csv', index = False)
